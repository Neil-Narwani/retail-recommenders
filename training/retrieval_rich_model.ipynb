# %%
import os
import pprint
import tempfile
import datetime
from typing import Dict, Text

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_recommenders as tfrs
from tensorboard.plugins.hparams import api as hp
import statistics as stats
import yaml

# %%
train_filename = "../data/samples/train_transactions.tfrecord"
train = tf.data.TFRecordDataset(train_filename)

test_filename = "../data/samples/test_transactions.tfrecord"
test = tf.data.TFRecordDataset(test_filename)

validation_filename = "../data/samples/validation_transactions.tfrecord"
validation = tf.data.TFRecordDataset(validation_filename)

feature_description = {
    'context_item_id': tf.io.FixedLenFeature([10], tf.int64, default_value=np.repeat(0, 10)),    
    'context_item_quantity': tf.io.FixedLenFeature([10], tf.float32, default_value=np.repeat(0, 10)),
    'context_item_price': tf.io.FixedLenFeature([10], tf.float32, default_value=np.repeat(0, 10)),    
    'context_item_department_id': tf.io.FixedLenFeature([10], tf.int64, default_value=np.repeat(0, 10)),
    'label_item_id': tf.io.FixedLenFeature([1], tf.int64, default_value=0),
}

def _parse_function(example_proto):
  return tf.io.parse_single_example(example_proto, feature_description)
def _map_function(x):
  return {
    "context_item_id": tf.strings.as_string(x["context_item_id"]),
    "context_item_price": x["context_item_price"],
    "context_item_department_id": x["context_item_department_id"],
    "label_item_id": tf.strings.as_string(x["label_item_id"])}
    
train_ds = train.map(_parse_function).map(_map_function)
test_ds = test.map(_parse_function).map(_map_function)
cached_train = train_ds.shuffle(10_000).batch(12800).cache()
cached_test = test_ds.batch(2560).cache()
cached_validation = validation.map(_parse_function).map(_map_function).batch(1280).cache()

# %%
items_filename = "../data/samples/items.tfrecord"
items_tf = tf.data.TFRecordDataset(items_filename)
item_feature_description = {
    'item_id': tf.io.FixedLenFeature([1], tf.int64, default_value=0),
    'item_fullprice': tf.io.FixedLenFeature([1], tf.float32, default_value=0.0 )
}

def item_parse_function(example_proto):
  return tf.io.parse_single_example(example_proto, item_feature_description)

items_ds = items_tf.map(item_parse_function).map(lambda x: {
    "item_id": tf.strings.as_string(x["item_id"]),
    "item_fullprice": x["item_fullprice"]
})
item_ids = items_ds.map(lambda x: x["item_id"]).batch(1_000)
unique_item_ids = np.unique(np.concatenate(list(item_ids)))
item_prices = np.concatenate(list(items_ds.map(lambda x: x["item_fullprice"]).batch(1000)))

dept_filename = "../data/samples/departments.tfrecord"
departments_tf = tf.data.TFRecordDataset(dept_filename)
dept_feature_description = {
  'dept_id' : tf.io.FixedLenFeature([1], tf.int64, default_value=0)
}
def dept_parse_function(example_proto):
  return tf.io.parse_single_example(example_proto, dept_feature_description)
department_ids = np.concatenate(list(departments_tf.map(dept_parse_function).map(lambda x: x['dept_id'])))

# %%
class ItemEmbeddingModel(tf.keras.Model):
  embedding_dimension = 32
  def __init__(self):
    super().__init__()

    self.item_embedding = tf.keras.Sequential([
      tf.keras.layers.StringLookup(vocabulary=unique_item_ids, mask_token=None, name='item_id_string_lookup'),
      tf.keras.layers.Embedding(len(unique_item_ids) + 1, self.embedding_dimension, name='item_id_embedding'),
      tf.keras.layers.GRU(self.embedding_dimension, name='item_id_rnn'),
    ], name='item_embedding')

    self.price_normalization = tf.keras.layers.Normalization(axis=-1)

    self.price_embedding = tf.keras.Sequential([
      self.price_normalization,
      tf.keras.layers.Embedding(len(item_prices)+1,output_dim=self.embedding_dimension, mask_zero=True),
      tf.keras.layers.GRU(self.embedding_dimension, name='item_price_rnn')
    ], name='price_embedding')    

    self.price_normalization.adapt(item_prices)

    self.dept_categorical = tf.keras.layers.IntegerLookup(max_tokens=len(department_ids)+1, vocabulary=department_ids)

    self.dept_embedding = tf.keras.Sequential([
      self.dept_categorical,
      tf.keras.layers.Embedding(len(department_ids)+1, output_dim=self.embedding_dimension, mask_zero=True),
      tf.keras.layers.GRU(self.embedding_dimension, name='dept_rnn')
    ])

  def call(self, features):
    return tf.concat([
        self.item_embedding(features["context_item_id"]),
        self.price_embedding(features["context_item_price"]),
        self.dept_embedding(features['context_item_department_id'])
    ], axis=1)

class DeepLayerModel(tf.keras.Model):
  """Model for encoding user queries."""

  def __init__(self, layer_sizes, embedding_model):
    """Model for encoding user queries.

    Args:
      layer_sizes:
        A list of integers where the i-th entry represents the number of units
        the i-th layer contains.
    """
    super().__init__()

    # We first use the user model for generating embeddings.
    self.embedding_model = embedding_model

    # Then construct the layers.
    self.dense_layers = tf.keras.Sequential()

    # Use the ReLU activation for all but the last layer.
    for layer_size in layer_sizes[:-1]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size, activation="relu"))

    # No activation for the last layer.
    for layer_size in layer_sizes[-1:]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size))

  def call(self, inputs):
    feature_embedding = self.embedding_model(inputs)
    return self.dense_layers(feature_embedding)

# %%
class RetrievalModel(tfrs.Model):
    def __init__(self, deep_layers):
        self.embedding_dim = 32
        super().__init__()
        self._query_model = DeepLayerModel(deep_layers, ItemEmbeddingModel())
        self._candidate_model = tf.keras.Sequential([
            tf.keras.layers.StringLookup(vocabulary=unique_item_ids, mask_token=None, name='candidate_itemid_lookup'),
            tf.keras.layers.Embedding(len(unique_item_ids) + 1, 32, name='candidate_embedding_lookup'),
            tf.keras.layers.Dense(self.embedding_dim)
            ], name='candidate_model')
        metrics = tfrs.metrics.FactorizedTopK(candidates=items_tf.batch(128).map(self._candidate_model))
        self._task = tfrs.tasks.Retrieval(metrics=metrics)

    def compute_loss(self, features, training=False):
        item_history = {
            "context_item_id": features["context_item_id"],
            "context_item_price": features["context_item_price"],
            "context_item_department_id" : features["context_item_department_id"]}   
        next_item_label = features["label_item_id"]

        query_embedding = self._query_model(item_history)       
        candidate_embedding = self._candidate_model(next_item_label)

        return self._task(query_embedding, candidate_embedding, compute_metrics=not training)

# %%
log_base = "../logs/fit/"
with open('epoch_tests.yaml', 'r') as stream:
    config = yaml.safe_load(stream)

for experiment in config['experiments']:
    log_dir = os.path.join(log_base, experiment['name'])
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
    model = RetrievalModel(experiment['deep_layers'])
    model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=experiment['learning_rate']))
    model.fit(cached_train, epochs=experiment['epochs'], validation_data=cached_validation, callbacks=[tensorboard_callback], verbose=1)
    experiment['evaluation'] = model.evaluate(cached_test, return_dict=True)

with open('../logs/epoch_test_results.yaml', 'w') as stream:
    yaml.dump(config, stream)
# Out:
# Epoch 1/36
# 78/78 [==============================] - 207s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 118542.8226 - regularization_loss: 0.0000e+00 - total_loss: 118542.8226 - val_factorized_top_k/top_1_categorical_accuracy: 0.9123 - val_factorized_top_k/top_5_categorical_accuracy: 0.9123 - val_factorized_top_k/top_10_categorical_accuracy: 0.9123 - val_factorized_top_k/top_50_categorical_accuracy: 0.9123 - val_factorized_top_k/top_100_categorical_accuracy: 0.9123 - val_loss: 11.4818 - val_regularization_loss: 0.0000e+00 - val_total_loss: 11.4818
# Epoch 2/36
# 78/78 [==============================] - 156s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 108122.6245 - regularization_loss: 0.0000e+00 - total_loss: 108122.6245 - val_factorized_top_k/top_1_categorical_accuracy: 0.9173 - val_factorized_top_k/top_5_categorical_accuracy: 0.9173 - val_factorized_top_k/top_10_categorical_accuracy: 0.9173 - val_factorized_top_k/top_50_categorical_accuracy: 0.9173 - val_factorized_top_k/top_100_categorical_accuracy: 0.9173 - val_loss: 11.6719 - val_regularization_loss: 0.0000e+00 - val_total_loss: 11.6719
# Epoch 3/36
# 78/78 [==============================] - 156s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 104080.0315 - regularization_loss: 0.0000e+00 - total_loss: 104080.0315 - val_factorized_top_k/top_1_categorical_accuracy: 0.9235 - val_factorized_top_k/top_5_categorical_accuracy: 0.9235 - val_factorized_top_k/top_10_categorical_accuracy: 0.9235 - val_factorized_top_k/top_50_categorical_accuracy: 0.9235 - val_factorized_top_k/top_100_categorical_accuracy: 0.9235 - val_loss: 10.6644 - val_regularization_loss: 0.0000e+00 - val_total_loss: 10.6644
# Epoch 4/36
# 78/78 [==============================] - 157s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 101534.7499 - regularization_loss: 0.0000e+00 - total_loss: 101534.7499 - val_factorized_top_k/top_1_categorical_accuracy: 0.9302 - val_factorized_top_k/top_5_categorical_accuracy: 0.9302 - val_factorized_top_k/top_10_categorical_accuracy: 0.9302 - val_factorized_top_k/top_50_categorical_accuracy: 0.9302 - val_factorized_top_k/top_100_categorical_accuracy: 0.9302 - val_loss: 11.8868 - val_regularization_loss: 0.0000e+00 - val_total_loss: 11.8868
# Epoch 5/36
# 78/78 [==============================] - 156s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 99670.9199 - regularization_loss: 0.0000e+00 - total_loss: 99670.9199 - val_factorized_top_k/top_1_categorical_accuracy: 0.9285 - val_factorized_top_k/top_5_categorical_accuracy: 0.9285 - val_factorized_top_k/top_10_categorical_accuracy: 0.9285 - val_factorized_top_k/top_50_categorical_accuracy: 0.9285 - val_factorized_top_k/top_100_categorical_accuracy: 0.9285 - val_loss: 13.2848 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.2848
# Epoch 6/36
# 78/78 [==============================] - 156s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 98261.4973 - regularization_loss: 0.0000e+00 - total_loss: 98261.4973 - val_factorized_top_k/top_1_categorical_accuracy: 0.9211 - val_factorized_top_k/top_5_categorical_accuracy: 0.9211 - val_factorized_top_k/top_10_categorical_accuracy: 0.9211 - val_factorized_top_k/top_50_categorical_accuracy: 0.9211 - val_factorized_top_k/top_100_categorical_accuracy: 0.9211 - val_loss: 13.9201 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.9201
# Epoch 7/36
# 78/78 [==============================] - 157s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 97112.5676 - regularization_loss: 0.0000e+00 - total_loss: 97112.5676 - val_factorized_top_k/top_1_categorical_accuracy: 0.9243 - val_factorized_top_k/top_5_categorical_accuracy: 0.9243 - val_factorized_top_k/top_10_categorical_accuracy: 0.9243 - val_factorized_top_k/top_50_categorical_accuracy: 0.9243 - val_factorized_top_k/top_100_categorical_accuracy: 0.9243 - val_loss: 13.3880 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.3880
# Epoch 8/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 96192.4804 - regularization_loss: 0.0000e+00 - total_loss: 96192.4804 - val_factorized_top_k/top_1_categorical_accuracy: 0.9219 - val_factorized_top_k/top_5_categorical_accuracy: 0.9219 - val_factorized_top_k/top_10_categorical_accuracy: 0.9219 - val_factorized_top_k/top_50_categorical_accuracy: 0.9219 - val_factorized_top_k/top_100_categorical_accuracy: 0.9219 - val_loss: 13.6548 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.6548
# Epoch 9/36
# 78/78 [==============================] - 157s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 95341.9144 - regularization_loss: 0.0000e+00 - total_loss: 95341.9144 - val_factorized_top_k/top_1_categorical_accuracy: 0.9258 - val_factorized_top_k/top_5_categorical_accuracy: 0.9258 - val_factorized_top_k/top_10_categorical_accuracy: 0.9258 - val_factorized_top_k/top_50_categorical_accuracy: 0.9258 - val_factorized_top_k/top_100_categorical_accuracy: 0.9258 - val_loss: 13.2647 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.2647
# Epoch 10/36
# 78/78 [==============================] - 157s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 94661.3499 - regularization_loss: 0.0000e+00 - total_loss: 94661.3499 - val_factorized_top_k/top_1_categorical_accuracy: 0.9223 - val_factorized_top_k/top_5_categorical_accuracy: 0.9223 - val_factorized_top_k/top_10_categorical_accuracy: 0.9223 - val_factorized_top_k/top_50_categorical_accuracy: 0.9223 - val_factorized_top_k/top_100_categorical_accuracy: 0.9223 - val_loss: 13.5280 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.5280
# Epoch 11/36
# 78/78 [==============================] - 157s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 94032.6964 - regularization_loss: 0.0000e+00 - total_loss: 94032.6964 - val_factorized_top_k/top_1_categorical_accuracy: 0.9229 - val_factorized_top_k/top_5_categorical_accuracy: 0.9229 - val_factorized_top_k/top_10_categorical_accuracy: 0.9229 - val_factorized_top_k/top_50_categorical_accuracy: 0.9229 - val_factorized_top_k/top_100_categorical_accuracy: 0.9229 - val_loss: 13.8254 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.8254
# Epoch 12/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 93461.9536 - regularization_loss: 0.0000e+00 - total_loss: 93461.9536 - val_factorized_top_k/top_1_categorical_accuracy: 0.9206 - val_factorized_top_k/top_5_categorical_accuracy: 0.9206 - val_factorized_top_k/top_10_categorical_accuracy: 0.9206 - val_factorized_top_k/top_50_categorical_accuracy: 0.9206 - val_factorized_top_k/top_100_categorical_accuracy: 0.9206 - val_loss: 13.5025 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.5025
# Epoch 13/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 92934.9755 - regularization_loss: 0.0000e+00 - total_loss: 92934.9755 - val_factorized_top_k/top_1_categorical_accuracy: 0.9236 - val_factorized_top_k/top_5_categorical_accuracy: 0.9236 - val_factorized_top_k/top_10_categorical_accuracy: 0.9236 - val_factorized_top_k/top_50_categorical_accuracy: 0.9236 - val_factorized_top_k/top_100_categorical_accuracy: 0.9236 - val_loss: 13.7522 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.7522
# Epoch 14/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 92455.4728 - regularization_loss: 0.0000e+00 - total_loss: 92455.4728 - val_factorized_top_k/top_1_categorical_accuracy: 0.9218 - val_factorized_top_k/top_5_categorical_accuracy: 0.9218 - val_factorized_top_k/top_10_categorical_accuracy: 0.9218 - val_factorized_top_k/top_50_categorical_accuracy: 0.9218 - val_factorized_top_k/top_100_categorical_accuracy: 0.9218 - val_loss: 14.0749 - val_regularization_loss: 0.0000e+00 - val_total_loss: 14.0749
# Epoch 15/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 92045.6983 - regularization_loss: 0.0000e+00 - total_loss: 92045.6983 - val_factorized_top_k/top_1_categorical_accuracy: 0.9224 - val_factorized_top_k/top_5_categorical_accuracy: 0.9224 - val_factorized_top_k/top_10_categorical_accuracy: 0.9224 - val_factorized_top_k/top_50_categorical_accuracy: 0.9224 - val_factorized_top_k/top_100_categorical_accuracy: 0.9224 - val_loss: 13.7668 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.7668
# Epoch 16/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 91615.5596 - regularization_loss: 0.0000e+00 - total_loss: 91615.5596 - val_factorized_top_k/top_1_categorical_accuracy: 0.9227 - val_factorized_top_k/top_5_categorical_accuracy: 0.9227 - val_factorized_top_k/top_10_categorical_accuracy: 0.9227 - val_factorized_top_k/top_50_categorical_accuracy: 0.9227 - val_factorized_top_k/top_100_categorical_accuracy: 0.9227 - val_loss: 14.1136 - val_regularization_loss: 0.0000e+00 - val_total_loss: 14.1136
# Epoch 17/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 91245.6443 - regularization_loss: 0.0000e+00 - total_loss: 91245.6443 - val_factorized_top_k/top_1_categorical_accuracy: 0.9228 - val_factorized_top_k/top_5_categorical_accuracy: 0.9228 - val_factorized_top_k/top_10_categorical_accuracy: 0.9228 - val_factorized_top_k/top_50_categorical_accuracy: 0.9228 - val_factorized_top_k/top_100_categorical_accuracy: 0.9228 - val_loss: 13.9421 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.9421
# Epoch 18/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 90901.4529 - regularization_loss: 0.0000e+00 - total_loss: 90901.4529 - val_factorized_top_k/top_1_categorical_accuracy: 0.9218 - val_factorized_top_k/top_5_categorical_accuracy: 0.9218 - val_factorized_top_k/top_10_categorical_accuracy: 0.9218 - val_factorized_top_k/top_50_categorical_accuracy: 0.9218 - val_factorized_top_k/top_100_categorical_accuracy: 0.9218 - val_loss: 14.1565 - val_regularization_loss: 0.0000e+00 - val_total_loss: 14.1565
# Epoch 19/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 90597.3847 - regularization_loss: 0.0000e+00 - total_loss: 90597.3847 - val_factorized_top_k/top_1_categorical_accuracy: 0.9203 - val_factorized_top_k/top_5_categorical_accuracy: 0.9203 - val_factorized_top_k/top_10_categorical_accuracy: 0.9203 - val_factorized_top_k/top_50_categorical_accuracy: 0.9203 - val_factorized_top_k/top_100_categorical_accuracy: 0.9203 - val_loss: 13.6157 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.6157
# Epoch 20/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 90267.0874 - regularization_loss: 0.0000e+00 - total_loss: 90267.0874 - val_factorized_top_k/top_1_categorical_accuracy: 0.9220 - val_factorized_top_k/top_5_categorical_accuracy: 0.9220 - val_factorized_top_k/top_10_categorical_accuracy: 0.9220 - val_factorized_top_k/top_50_categorical_accuracy: 0.9220 - val_factorized_top_k/top_100_categorical_accuracy: 0.9220 - val_loss: 13.9229 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.9229
# Epoch 21/36
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 89990.8283 - regularization_loss: 0.0000e+00 - total_loss: 89990.8283 - val_factorized_top_k/top_1_categorical_accuracy: 0.9226 - val_factorized_top_k/top_5_categorical_accuracy: 0.9226 - val_factorized_top_k/top_10_categorical_accuracy: 0.9226 - val_factorized_top_k/top_50_categorical_accuracy: 0.9226 - val_factorized_top_k/top_100_categorical_accuracy: 0.9226 - val_loss: 13.5754 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.5754
# Epoch 22/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 89731.4523 - regularization_loss: 0.0000e+00 - total_loss: 89731.4523 - val_factorized_top_k/top_1_categorical_accuracy: 0.9221 - val_factorized_top_k/top_5_categorical_accuracy: 0.9221 - val_factorized_top_k/top_10_categorical_accuracy: 0.9221 - val_factorized_top_k/top_50_categorical_accuracy: 0.9221 - val_factorized_top_k/top_100_categorical_accuracy: 0.9221 - val_loss: 13.7005 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.7005
# Epoch 23/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 89479.9450 - regularization_loss: 0.0000e+00 - total_loss: 89479.9450 - val_factorized_top_k/top_1_categorical_accuracy: 0.9229 - val_factorized_top_k/top_5_categorical_accuracy: 0.9229 - val_factorized_top_k/top_10_categorical_accuracy: 0.9229 - val_factorized_top_k/top_50_categorical_accuracy: 0.9229 - val_factorized_top_k/top_100_categorical_accuracy: 0.9229 - val_loss: 13.6660 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.6660
# Epoch 24/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 89247.0717 - regularization_loss: 0.0000e+00 - total_loss: 89247.0717 - val_factorized_top_k/top_1_categorical_accuracy: 0.9205 - val_factorized_top_k/top_5_categorical_accuracy: 0.9205 - val_factorized_top_k/top_10_categorical_accuracy: 0.9205 - val_factorized_top_k/top_50_categorical_accuracy: 0.9205 - val_factorized_top_k/top_100_categorical_accuracy: 0.9205 - val_loss: 13.4787 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.4787
# Epoch 25/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 89013.7796 - regularization_loss: 0.0000e+00 - total_loss: 89013.7796 - val_factorized_top_k/top_1_categorical_accuracy: 0.9236 - val_factorized_top_k/top_5_categorical_accuracy: 0.9236 - val_factorized_top_k/top_10_categorical_accuracy: 0.9236 - val_factorized_top_k/top_50_categorical_accuracy: 0.9236 - val_factorized_top_k/top_100_categorical_accuracy: 0.9236 - val_loss: 13.6720 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.6720
# Epoch 26/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 88807.3412 - regularization_loss: 0.0000e+00 - total_loss: 88807.3412 - val_factorized_top_k/top_1_categorical_accuracy: 0.9212 - val_factorized_top_k/top_5_categorical_accuracy: 0.9212 - val_factorized_top_k/top_10_categorical_accuracy: 0.9212 - val_factorized_top_k/top_50_categorical_accuracy: 0.9212 - val_factorized_top_k/top_100_categorical_accuracy: 0.9212 - val_loss: 13.5690 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.5690
# Epoch 27/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 88613.3737 - regularization_loss: 0.0000e+00 - total_loss: 88613.3737 - val_factorized_top_k/top_1_categorical_accuracy: 0.9222 - val_factorized_top_k/top_5_categorical_accuracy: 0.9222 - val_factorized_top_k/top_10_categorical_accuracy: 0.9222 - val_factorized_top_k/top_50_categorical_accuracy: 0.9222 - val_factorized_top_k/top_100_categorical_accuracy: 0.9222 - val_loss: 13.6213 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.6213
# Epoch 28/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 88417.3810 - regularization_loss: 0.0000e+00 - total_loss: 88417.3810 - val_factorized_top_k/top_1_categorical_accuracy: 0.9212 - val_factorized_top_k/top_5_categorical_accuracy: 0.9212 - val_factorized_top_k/top_10_categorical_accuracy: 0.9212 - val_factorized_top_k/top_50_categorical_accuracy: 0.9212 - val_factorized_top_k/top_100_categorical_accuracy: 0.9212 - val_loss: 13.4423 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.4423
# Epoch 29/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 88230.6897 - regularization_loss: 0.0000e+00 - total_loss: 88230.6897 - val_factorized_top_k/top_1_categorical_accuracy: 0.9222 - val_factorized_top_k/top_5_categorical_accuracy: 0.9222 - val_factorized_top_k/top_10_categorical_accuracy: 0.9222 - val_factorized_top_k/top_50_categorical_accuracy: 0.9222 - val_factorized_top_k/top_100_categorical_accuracy: 0.9222 - val_loss: 13.7109 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.7109
# Epoch 30/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 88047.2448 - regularization_loss: 0.0000e+00 - total_loss: 88047.2448 - val_factorized_top_k/top_1_categorical_accuracy: 0.9222 - val_factorized_top_k/top_5_categorical_accuracy: 0.9222 - val_factorized_top_k/top_10_categorical_accuracy: 0.9222 - val_factorized_top_k/top_50_categorical_accuracy: 0.9222 - val_factorized_top_k/top_100_categorical_accuracy: 0.9222 - val_loss: 13.5741 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.5741
# Epoch 31/36
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 87878.6946 - regularization_loss: 0.0000e+00 - total_loss: 87878.6946 - val_factorized_top_k/top_1_categorical_accuracy: 0.9220 - val_factorized_top_k/top_5_categorical_accuracy: 0.9220 - val_factorized_top_k/top_10_categorical_accuracy: 0.9220 - val_factorized_top_k/top_50_categorical_accuracy: 0.9220 - val_factorized_top_k/top_100_categorical_accuracy: 0.9220 - val_loss: 13.5447 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.5447
# Epoch 32/36
# 78/78 [==============================] - 158s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 87707.1502 - regularization_loss: 0.0000e+00 - total_loss: 87707.1502 - val_factorized_top_k/top_1_categorical_accuracy: 0.9221 - val_factorized_top_k/top_5_categorical_accuracy: 0.9221 - val_factorized_top_k/top_10_categorical_accuracy: 0.9221 - val_factorized_top_k/top_50_categorical_accuracy: 0.9221 - val_factorized_top_k/top_100_categorical_accuracy: 0.9221 - val_loss: 13.4333 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.4333
# Epoch 33/36
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 87553.7280 - regularization_loss: 0.0000e+00 - total_loss: 87553.7280 - val_factorized_top_k/top_1_categorical_accuracy: 0.9223 - val_factorized_top_k/top_5_categorical_accuracy: 0.9223 - val_factorized_top_k/top_10_categorical_accuracy: 0.9223 - val_factorized_top_k/top_50_categorical_accuracy: 0.9223 - val_factorized_top_k/top_100_categorical_accuracy: 0.9223 - val_loss: 13.3358 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.3358
# Epoch 34/36
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 87402.9265 - regularization_loss: 0.0000e+00 - total_loss: 87402.9265 - val_factorized_top_k/top_1_categorical_accuracy: 0.9228 - val_factorized_top_k/top_5_categorical_accuracy: 0.9228 - val_factorized_top_k/top_10_categorical_accuracy: 0.9228 - val_factorized_top_k/top_50_categorical_accuracy: 0.9228 - val_factorized_top_k/top_100_categorical_accuracy: 0.9228 - val_loss: 13.4500 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.4500
# Epoch 35/36
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 87266.9316 - regularization_loss: 0.0000e+00 - total_loss: 87266.9316 - val_factorized_top_k/top_1_categorical_accuracy: 0.9219 - val_factorized_top_k/top_5_categorical_accuracy: 0.9219 - val_factorized_top_k/top_10_categorical_accuracy: 0.9219 - val_factorized_top_k/top_50_categorical_accuracy: 0.9219 - val_factorized_top_k/top_100_categorical_accuracy: 0.9219 - val_loss: 13.5589 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.5589
# Epoch 36/36
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 87122.6945 - regularization_loss: 0.0000e+00 - total_loss: 87122.6945 - val_factorized_top_k/top_1_categorical_accuracy: 0.9230 - val_factorized_top_k/top_5_categorical_accuracy: 0.9230 - val_factorized_top_k/top_10_categorical_accuracy: 0.9230 - val_factorized_top_k/top_50_categorical_accuracy: 0.9230 - val_factorized_top_k/top_100_categorical_accuracy: 0.9230 - val_loss: 13.4291 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.4291
# 110/110 [==============================] - 251s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.9228 - factorized_top_k/top_5_categorical_accuracy: 0.9228 - factorized_top_k/top_10_categorical_accuracy: 0.9228 - factorized_top_k/top_50_categorical_accuracy: 0.9228 - factorized_top_k/top_100_categorical_accuracy: 0.9228 - loss: 16625.7514 - regularization_loss: 0.0000e+00 - total_loss: 16625.7514
# Epoch 1/48
# 78/78 [==============================] - 171s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 129408.2035 - regularization_loss: 0.0000e+00 - total_loss: 129408.2035 - val_factorized_top_k/top_1_categorical_accuracy: 0.9057 - val_factorized_top_k/top_5_categorical_accuracy: 0.9057 - val_factorized_top_k/top_10_categorical_accuracy: 0.9057 - val_factorized_top_k/top_50_categorical_accuracy: 0.9057 - val_factorized_top_k/top_100_categorical_accuracy: 0.9057 - val_loss: 10.7715 - val_regularization_loss: 0.0000e+00 - val_total_loss: 10.7715
# Epoch 2/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 114273.1741 - regularization_loss: 0.0000e+00 - total_loss: 114273.1741 - val_factorized_top_k/top_1_categorical_accuracy: 0.9360 - val_factorized_top_k/top_5_categorical_accuracy: 0.9360 - val_factorized_top_k/top_10_categorical_accuracy: 0.9360 - val_factorized_top_k/top_50_categorical_accuracy: 0.9360 - val_factorized_top_k/top_100_categorical_accuracy: 0.9360 - val_loss: 10.6827 - val_regularization_loss: 0.0000e+00 - val_total_loss: 10.6827
# Epoch 3/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 112345.6730 - regularization_loss: 0.0000e+00 - total_loss: 112345.6730 - val_factorized_top_k/top_1_categorical_accuracy: 0.9369 - val_factorized_top_k/top_5_categorical_accuracy: 0.9369 - val_factorized_top_k/top_10_categorical_accuracy: 0.9369 - val_factorized_top_k/top_50_categorical_accuracy: 0.9369 - val_factorized_top_k/top_100_categorical_accuracy: 0.9369 - val_loss: 11.7123 - val_regularization_loss: 0.0000e+00 - val_total_loss: 11.7123
# Epoch 4/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 110239.5777 - regularization_loss: 0.0000e+00 - total_loss: 110239.5777 - val_factorized_top_k/top_1_categorical_accuracy: 0.9297 - val_factorized_top_k/top_5_categorical_accuracy: 0.9297 - val_factorized_top_k/top_10_categorical_accuracy: 0.9297 - val_factorized_top_k/top_50_categorical_accuracy: 0.9297 - val_factorized_top_k/top_100_categorical_accuracy: 0.9297 - val_loss: 13.0107 - val_regularization_loss: 0.0000e+00 - val_total_loss: 13.0107
# Epoch 5/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 108515.1931 - regularization_loss: 0.0000e+00 - total_loss: 108515.1931 - val_factorized_top_k/top_1_categorical_accuracy: 0.9285 - val_factorized_top_k/top_5_categorical_accuracy: 0.9285 - val_factorized_top_k/top_10_categorical_accuracy: 0.9285 - val_factorized_top_k/top_50_categorical_accuracy: 0.9285 - val_factorized_top_k/top_100_categorical_accuracy: 0.9285 - val_loss: 11.4129 - val_regularization_loss: 0.0000e+00 - val_total_loss: 11.4129
# Epoch 6/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 107133.1676 - regularization_loss: 0.0000e+00 - total_loss: 107133.1676 - val_factorized_top_k/top_1_categorical_accuracy: 0.9282 - val_factorized_top_k/top_5_categorical_accuracy: 0.9282 - val_factorized_top_k/top_10_categorical_accuracy: 0.9282 - val_factorized_top_k/top_50_categorical_accuracy: 0.9282 - val_factorized_top_k/top_100_categorical_accuracy: 0.9282 - val_loss: 10.3323 - val_regularization_loss: 0.0000e+00 - val_total_loss: 10.3323
# Epoch 7/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 105946.5862 - regularization_loss: 0.0000e+00 - total_loss: 105946.5862 - val_factorized_top_k/top_1_categorical_accuracy: 0.9313 - val_factorized_top_k/top_5_categorical_accuracy: 0.9313 - val_factorized_top_k/top_10_categorical_accuracy: 0.9313 - val_factorized_top_k/top_50_categorical_accuracy: 0.9313 - val_factorized_top_k/top_100_categorical_accuracy: 0.9313 - val_loss: 8.7829 - val_regularization_loss: 0.0000e+00 - val_total_loss: 8.7829
# Epoch 8/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 104892.4696 - regularization_loss: 0.0000e+00 - total_loss: 104892.4696 - val_factorized_top_k/top_1_categorical_accuracy: 0.9351 - val_factorized_top_k/top_5_categorical_accuracy: 0.9351 - val_factorized_top_k/top_10_categorical_accuracy: 0.9351 - val_factorized_top_k/top_50_categorical_accuracy: 0.9351 - val_factorized_top_k/top_100_categorical_accuracy: 0.9351 - val_loss: 8.5267 - val_regularization_loss: 0.0000e+00 - val_total_loss: 8.5267
# Epoch 9/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 103891.7740 - regularization_loss: 0.0000e+00 - total_loss: 103891.7740 - val_factorized_top_k/top_1_categorical_accuracy: 0.9323 - val_factorized_top_k/top_5_categorical_accuracy: 0.9323 - val_factorized_top_k/top_10_categorical_accuracy: 0.9323 - val_factorized_top_k/top_50_categorical_accuracy: 0.9323 - val_factorized_top_k/top_100_categorical_accuracy: 0.9323 - val_loss: 8.1361 - val_regularization_loss: 0.0000e+00 - val_total_loss: 8.1361
# Epoch 10/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 103057.3657 - regularization_loss: 0.0000e+00 - total_loss: 103057.3657 - val_factorized_top_k/top_1_categorical_accuracy: 0.9328 - val_factorized_top_k/top_5_categorical_accuracy: 0.9328 - val_factorized_top_k/top_10_categorical_accuracy: 0.9328 - val_factorized_top_k/top_50_categorical_accuracy: 0.9328 - val_factorized_top_k/top_100_categorical_accuracy: 0.9328 - val_loss: 8.1474 - val_regularization_loss: 0.0000e+00 - val_total_loss: 8.1474
# Epoch 11/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 102410.8904 - regularization_loss: 0.0000e+00 - total_loss: 102410.8904 - val_factorized_top_k/top_1_categorical_accuracy: 0.9343 - val_factorized_top_k/top_5_categorical_accuracy: 0.9343 - val_factorized_top_k/top_10_categorical_accuracy: 0.9343 - val_factorized_top_k/top_50_categorical_accuracy: 0.9343 - val_factorized_top_k/top_100_categorical_accuracy: 0.9343 - val_loss: 8.5754 - val_regularization_loss: 0.0000e+00 - val_total_loss: 8.5754
# Epoch 12/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 101657.0632 - regularization_loss: 0.0000e+00 - total_loss: 101657.0632 - val_factorized_top_k/top_1_categorical_accuracy: 0.9348 - val_factorized_top_k/top_5_categorical_accuracy: 0.9348 - val_factorized_top_k/top_10_categorical_accuracy: 0.9348 - val_factorized_top_k/top_50_categorical_accuracy: 0.9348 - val_factorized_top_k/top_100_categorical_accuracy: 0.9348 - val_loss: 8.1916 - val_regularization_loss: 0.0000e+00 - val_total_loss: 8.1916
# Epoch 13/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 101037.0751 - regularization_loss: 0.0000e+00 - total_loss: 101037.0751 - val_factorized_top_k/top_1_categorical_accuracy: 0.9337 - val_factorized_top_k/top_5_categorical_accuracy: 0.9337 - val_factorized_top_k/top_10_categorical_accuracy: 0.9337 - val_factorized_top_k/top_50_categorical_accuracy: 0.9337 - val_factorized_top_k/top_100_categorical_accuracy: 0.9337 - val_loss: 9.1534 - val_regularization_loss: 0.0000e+00 - val_total_loss: 9.1534
# Epoch 14/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 100446.9700 - regularization_loss: 0.0000e+00 - total_loss: 100446.9700 - val_factorized_top_k/top_1_categorical_accuracy: 0.9333 - val_factorized_top_k/top_5_categorical_accuracy: 0.9333 - val_factorized_top_k/top_10_categorical_accuracy: 0.9333 - val_factorized_top_k/top_50_categorical_accuracy: 0.9333 - val_factorized_top_k/top_100_categorical_accuracy: 0.9333 - val_loss: 9.3687 - val_regularization_loss: 0.0000e+00 - val_total_loss: 9.3687
# Epoch 15/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 99874.2898 - regularization_loss: 0.0000e+00 - total_loss: 99874.2898 - val_factorized_top_k/top_1_categorical_accuracy: 0.9356 - val_factorized_top_k/top_5_categorical_accuracy: 0.9356 - val_factorized_top_k/top_10_categorical_accuracy: 0.9356 - val_factorized_top_k/top_50_categorical_accuracy: 0.9356 - val_factorized_top_k/top_100_categorical_accuracy: 0.9356 - val_loss: 9.5796 - val_regularization_loss: 0.0000e+00 - val_total_loss: 9.5796
# Epoch 16/48
# 78/78 [==============================] - 159s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 99321.9388 - regularization_loss: 0.0000e+00 - total_loss: 99321.9388 - val_factorized_top_k/top_1_categorical_accuracy: 0.9358 - val_factorized_top_k/top_5_categorical_accuracy: 0.9358 - val_factorized_top_k/top_10_categorical_accuracy: 0.9358 - val_factorized_top_k/top_50_categorical_accuracy: 0.9358 - val_factorized_top_k/top_100_categorical_accuracy: 0.9358 - val_loss: 10.2001 - val_regularization_loss: 0.0000e+00 - val_total_loss: 10.2001
# Epoch 17/48
# 78/78 [==============================] - 160s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 98766.0427 - regularization_loss: 0.0000e+00 - total_loss: 98766.0427 - val_factorized_top_k/top_1_categorical_accuracy: 0.9369 - val_factorized_top_k/top_5_categorical_accuracy: 0.9369 - val_factorized_top_k/top_10_categorical_accuracy: 0.9369 - val_factorized_top_k/top_50_categorical_accuracy: 0.9369 - val_factorized_top_k/top_100_categorical_accuracy: 0.9369 - val_loss: 10.1824 - val_regularization_loss: 0.0000e+00 - val_total_loss: 10.1824
# Epoch 18/48
# 78/78 [==============================] - 160s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 98368.9240 - regularization_loss: 0.0000e+00 - total_loss: 98368.9240 - val_factorized_top_k/top_1_categorical_accuracy: 0.9362 - val_factorized_top_k/top_5_categorical_accuracy: 0.9362 - val_factorized_top_k/top_10_categorical_accuracy: 0.9362 - val_factorized_top_k/top_50_categorical_accuracy: 0.9362 - val_factorized_top_k/top_100_categorical_accuracy: 0.9362 - val_loss: 9.7169 - val_regularization_loss: 0.0000e+00 - val_total_loss: 9.7169
# Epoch 19/48
# 78/78 [==============================] - 160s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 97920.2676 - regularization_loss: 0.0000e+00 - total_loss: 97920.2676 - val_factorized_top_k/top_1_categorical_accuracy: 0.9365 - val_factorized_top_k/top_5_categorical_accuracy: 0.9365 - val_factorized_top_k/top_10_categorical_accuracy: 0.9365 - val_factorized_top_k/top_50_categorical_accuracy: 0.9365 - val_factorized_top_k/top_100_categorical_accuracy: 0.9365 - val_loss: 10.6106 - val_regularization_loss: 0.0000e+00 - val_total_loss: 10.6106
# Epoch 20/48
# 78/78 [==============================] - 160s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 97514.8823 - regularization_loss: 0.0000e+00 - total_loss: 97514.8823 - val_factorized_top_k/top_1_categorical_accuracy: 0.9365 - val_factorized_top_k/top_5_categorical_accuracy: 0.9365 - val_factorized_top_k/top_10_categorical_accuracy: 0.9365 - val_factorized_top_k/top_50_categorical_accuracy: 0.9365 - val_factorized_top_k/top_100_categorical_accuracy: 0.9365 - val_loss: 10.2298 - val_regularization_loss: 0.0000e+00 - val_total_loss: 10.2298
# Epoch 21/48
# 78/78 [==============================] - 160s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 97179.0367 - regularization_loss: 0.0000e+00 - total_loss: 97179.0367 - val_factorized_top_k/top_1_categorical_accuracy: 0.9369 - val_factorized_top_k/top_5_categorical_accuracy: 0.9369 - val_factorized_top_k/top_10_categorical_accuracy: 0.9369 - val_factorized_top_k/top_50_categorical_accuracy: 0.9369 - val_factorized_top_k/top_100_categorical_accuracy: 0.9369 - val_loss: 10.3464 - val_regularization_loss: 0.0000e+00 - val_total_loss: 10.3464
# Epoch 22/48
# 78/78 [==============================] - 160s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 96832.8130 - regularization_loss: 0.0000e+00 - total_loss: 96832.8130 - val_factorized_top_k/top_1_categorical_accuracy: 0.9388 - val_factorized_top_k/top_5_categorical_accuracy: 0.9388 - val_factorized_top_k/top_10_categorical_accuracy: 0.9388 - val_factorized_top_k/top_50_categorical_accuracy: 0.9388 - val_factorized_top_k/top_100_categorical_accuracy: 0.9388 - val_loss: 11.4242 - val_regularization_loss: 0.0000e+00 - val_total_loss: 11.4242
# Epoch 23/48
# ...
# Epoch 78/96
# 78/78 [==============================] - 185s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85854.4467 - regularization_loss: 0.0000e+00 - total_loss: 85854.4467 - val_factorized_top_k/top_1_categorical_accuracy: 0.9465 - val_factorized_top_k/top_5_categorical_accuracy: 0.9465 - val_factorized_top_k/top_10_categorical_accuracy: 0.9465 - val_factorized_top_k/top_50_categorical_accuracy: 0.9465 - val_factorized_top_k/top_100_categorical_accuracy: 0.9465 - val_loss: 16.1723 - val_regularization_loss: 0.0000e+00 - val_total_loss: 16.1723
# Epoch 79/96
# 78/78 [==============================] - 186s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85801.6069 - regularization_loss: 0.0000e+00 - total_loss: 85801.6069 - val_factorized_top_k/top_1_categorical_accuracy: 0.9470 - val_factorized_top_k/top_5_categorical_accuracy: 0.9470 - val_factorized_top_k/top_10_categorical_accuracy: 0.9470 - val_factorized_top_k/top_50_categorical_accuracy: 0.9470 - val_factorized_top_k/top_100_categorical_accuracy: 0.9470 - val_loss: 16.2488 - val_regularization_loss: 0.0000e+00 - val_total_loss: 16.2488
# Epoch 80/96
# 78/78 [==============================] - 187s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85753.4002 - regularization_loss: 0.0000e+00 - total_loss: 85753.4002 - val_factorized_top_k/top_1_categorical_accuracy: 0.9469 - val_factorized_top_k/top_5_categorical_accuracy: 0.9469 - val_factorized_top_k/top_10_categorical_accuracy: 0.9469 - val_factorized_top_k/top_50_categorical_accuracy: 0.9469 - val_factorized_top_k/top_100_categorical_accuracy: 0.9469 - val_loss: 16.3748 - val_regularization_loss: 0.0000e+00 - val_total_loss: 16.3748
# Epoch 81/96
# 78/78 [==============================] - 186s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85698.1591 - regularization_loss: 0.0000e+00 - total_loss: 85698.1591 - val_factorized_top_k/top_1_categorical_accuracy: 0.9467 - val_factorized_top_k/top_5_categorical_accuracy: 0.9467 - val_factorized_top_k/top_10_categorical_accuracy: 0.9467 - val_factorized_top_k/top_50_categorical_accuracy: 0.9467 - val_factorized_top_k/top_100_categorical_accuracy: 0.9467 - val_loss: 16.5746 - val_regularization_loss: 0.0000e+00 - val_total_loss: 16.5746
# Epoch 82/96
# 78/78 [==============================] - 187s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85649.9171 - regularization_loss: 0.0000e+00 - total_loss: 85649.9171 - val_factorized_top_k/top_1_categorical_accuracy: 0.9472 - val_factorized_top_k/top_5_categorical_accuracy: 0.9472 - val_factorized_top_k/top_10_categorical_accuracy: 0.9472 - val_factorized_top_k/top_50_categorical_accuracy: 0.9472 - val_factorized_top_k/top_100_categorical_accuracy: 0.9472 - val_loss: 16.5094 - val_regularization_loss: 0.0000e+00 - val_total_loss: 16.5094
# Epoch 83/96
# 78/78 [==============================] - 186s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85596.3364 - regularization_loss: 0.0000e+00 - total_loss: 85596.3364 - val_factorized_top_k/top_1_categorical_accuracy: 0.9468 - val_factorized_top_k/top_5_categorical_accuracy: 0.9468 - val_factorized_top_k/top_10_categorical_accuracy: 0.9468 - val_factorized_top_k/top_50_categorical_accuracy: 0.9468 - val_factorized_top_k/top_100_categorical_accuracy: 0.9468 - val_loss: 16.5898 - val_regularization_loss: 0.0000e+00 - val_total_loss: 16.5898
# Epoch 84/96
# 78/78 [==============================] - 188s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85554.0395 - regularization_loss: 0.0000e+00 - total_loss: 85554.0395 - val_factorized_top_k/top_1_categorical_accuracy: 0.9470 - val_factorized_top_k/top_5_categorical_accuracy: 0.9470 - val_factorized_top_k/top_10_categorical_accuracy: 0.9470 - val_factorized_top_k/top_50_categorical_accuracy: 0.9470 - val_factorized_top_k/top_100_categorical_accuracy: 0.9470 - val_loss: 16.7146 - val_regularization_loss: 0.0000e+00 - val_total_loss: 16.7146
# Epoch 85/96
# 78/78 [==============================] - 187s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85510.4577 - regularization_loss: 0.0000e+00 - total_loss: 85510.4577 - val_factorized_top_k/top_1_categorical_accuracy: 0.9470 - val_factorized_top_k/top_5_categorical_accuracy: 0.9470 - val_factorized_top_k/top_10_categorical_accuracy: 0.9470 - val_factorized_top_k/top_50_categorical_accuracy: 0.9470 - val_factorized_top_k/top_100_categorical_accuracy: 0.9470 - val_loss: 16.7932 - val_regularization_loss: 0.0000e+00 - val_total_loss: 16.7932
# Epoch 86/96
# 78/78 [==============================] - 187s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85456.9881 - regularization_loss: 0.0000e+00 - total_loss: 85456.9881 - val_factorized_top_k/top_1_categorical_accuracy: 0.9473 - val_factorized_top_k/top_5_categorical_accuracy: 0.9473 - val_factorized_top_k/top_10_categorical_accuracy: 0.9473 - val_factorized_top_k/top_50_categorical_accuracy: 0.9473 - val_factorized_top_k/top_100_categorical_accuracy: 0.9473 - val_loss: 16.9616 - val_regularization_loss: 0.0000e+00 - val_total_loss: 16.9616
# Epoch 87/96
# 78/78 [==============================] - 188s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85412.9267 - regularization_loss: 0.0000e+00 - total_loss: 85412.9267 - val_factorized_top_k/top_1_categorical_accuracy: 0.9474 - val_factorized_top_k/top_5_categorical_accuracy: 0.9474 - val_factorized_top_k/top_10_categorical_accuracy: 0.9474 - val_factorized_top_k/top_50_categorical_accuracy: 0.9474 - val_factorized_top_k/top_100_categorical_accuracy: 0.9474 - val_loss: 17.0001 - val_regularization_loss: 0.0000e+00 - val_total_loss: 17.0001
# Epoch 88/96
# 78/78 [==============================] - 187s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85368.0888 - regularization_loss: 0.0000e+00 - total_loss: 85368.0888 - val_factorized_top_k/top_1_categorical_accuracy: 0.9471 - val_factorized_top_k/top_5_categorical_accuracy: 0.9471 - val_factorized_top_k/top_10_categorical_accuracy: 0.9471 - val_factorized_top_k/top_50_categorical_accuracy: 0.9471 - val_factorized_top_k/top_100_categorical_accuracy: 0.9471 - val_loss: 17.1309 - val_regularization_loss: 0.0000e+00 - val_total_loss: 17.1309
# Epoch 89/96
# 78/78 [==============================] - 198s 3s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85328.9860 - regularization_loss: 0.0000e+00 - total_loss: 85328.9860 - val_factorized_top_k/top_1_categorical_accuracy: 0.9477 - val_factorized_top_k/top_5_categorical_accuracy: 0.9477 - val_factorized_top_k/top_10_categorical_accuracy: 0.9477 - val_factorized_top_k/top_50_categorical_accuracy: 0.9477 - val_factorized_top_k/top_100_categorical_accuracy: 0.9477 - val_loss: 17.1750 - val_regularization_loss: 0.0000e+00 - val_total_loss: 17.1750
# Epoch 90/96
# 78/78 [==============================] - 197s 3s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85282.6990 - regularization_loss: 0.0000e+00 - total_loss: 85282.6990 - val_factorized_top_k/top_1_categorical_accuracy: 0.9471 - val_factorized_top_k/top_5_categorical_accuracy: 0.9471 - val_factorized_top_k/top_10_categorical_accuracy: 0.9471 - val_factorized_top_k/top_50_categorical_accuracy: 0.9471 - val_factorized_top_k/top_100_categorical_accuracy: 0.9471 - val_loss: 17.2349 - val_regularization_loss: 0.0000e+00 - val_total_loss: 17.2349
# Epoch 91/96
# 78/78 [==============================] - 189s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85237.2808 - regularization_loss: 0.0000e+00 - total_loss: 85237.2808 - val_factorized_top_k/top_1_categorical_accuracy: 0.9478 - val_factorized_top_k/top_5_categorical_accuracy: 0.9478 - val_factorized_top_k/top_10_categorical_accuracy: 0.9478 - val_factorized_top_k/top_50_categorical_accuracy: 0.9478 - val_factorized_top_k/top_100_categorical_accuracy: 0.9478 - val_loss: 17.2190 - val_regularization_loss: 0.0000e+00 - val_total_loss: 17.2190
# Epoch 92/96
# 78/78 [==============================] - 191s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85194.0992 - regularization_loss: 0.0000e+00 - total_loss: 85194.0992 - val_factorized_top_k/top_1_categorical_accuracy: 0.9473 - val_factorized_top_k/top_5_categorical_accuracy: 0.9473 - val_factorized_top_k/top_10_categorical_accuracy: 0.9473 - val_factorized_top_k/top_50_categorical_accuracy: 0.9473 - val_factorized_top_k/top_100_categorical_accuracy: 0.9473 - val_loss: 17.3161 - val_regularization_loss: 0.0000e+00 - val_total_loss: 17.3161
# Epoch 93/96
# 78/78 [==============================] - 190s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85152.2304 - regularization_loss: 0.0000e+00 - total_loss: 85152.2304 - val_factorized_top_k/top_1_categorical_accuracy: 0.9473 - val_factorized_top_k/top_5_categorical_accuracy: 0.9473 - val_factorized_top_k/top_10_categorical_accuracy: 0.9473 - val_factorized_top_k/top_50_categorical_accuracy: 0.9473 - val_factorized_top_k/top_100_categorical_accuracy: 0.9473 - val_loss: 17.5007 - val_regularization_loss: 0.0000e+00 - val_total_loss: 17.5007
# Epoch 94/96
# 78/78 [==============================] - 191s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85112.9127 - regularization_loss: 0.0000e+00 - total_loss: 85112.9127 - val_factorized_top_k/top_1_categorical_accuracy: 0.9477 - val_factorized_top_k/top_5_categorical_accuracy: 0.9477 - val_factorized_top_k/top_10_categorical_accuracy: 0.9477 - val_factorized_top_k/top_50_categorical_accuracy: 0.9477 - val_factorized_top_k/top_100_categorical_accuracy: 0.9477 - val_loss: 17.4001 - val_regularization_loss: 0.0000e+00 - val_total_loss: 17.4001
# Epoch 95/96
# 78/78 [==============================] - 191s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85066.8533 - regularization_loss: 0.0000e+00 - total_loss: 85066.8533 - val_factorized_top_k/top_1_categorical_accuracy: 0.9471 - val_factorized_top_k/top_5_categorical_accuracy: 0.9471 - val_factorized_top_k/top_10_categorical_accuracy: 0.9471 - val_factorized_top_k/top_50_categorical_accuracy: 0.9471 - val_factorized_top_k/top_100_categorical_accuracy: 0.9471 - val_loss: 17.7036 - val_regularization_loss: 0.0000e+00 - val_total_loss: 17.7036
# Epoch 96/96
# 78/78 [==============================] - 191s 2s/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0000e+00 - loss: 85028.2733 - regularization_loss: 0.0000e+00 - total_loss: 85028.2733 - val_factorized_top_k/top_1_categorical_accuracy: 0.9475 - val_factorized_top_k/top_5_categorical_accuracy: 0.9475 - val_factorized_top_k/top_10_categorical_accuracy: 0.9475 - val_factorized_top_k/top_50_categorical_accuracy: 0.9475 - val_factorized_top_k/top_100_categorical_accuracy: 0.9475 - val_loss: 17.6181 - val_regularization_loss: 0.0000e+00 - val_total_loss: 17.6181
# 110/110 [==============================] - 277s 3s/step - factorized_top_k/top_1_categorical_accuracy: 0.9471 - factorized_top_k/top_5_categorical_accuracy: 0.9471 - factorized_top_k/top_10_categorical_accuracy: 0.9471 - factorized_top_k/top_50_categorical_accuracy: 0.9471 - factorized_top_k/top_100_categorical_accuracy: 0.9471 - loss: 17300.9412 - regularization_loss: 0.0000e+00 - total_loss: 17300.9412
